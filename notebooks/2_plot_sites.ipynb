# %% [markdown]
# ### Load interesting sites

# %%
import json
import pandas
sites_df = pandas.read_csv('interesting_sites.csv')
center = {"lat": (max(sites_df['lat']) + min(sites_df['lat'])) / 2, "lng": (max(sites_df['lon']) + min(sites_df['lon'])) / 2}
print("Center is %s"%center)
site_data = sites_df[['lat', 'lon', 'capacity', 'capacity_factor']].as_matrix().tolist()
print("Have %s sites"%len(site_data))
# Out:
# Center is {'lat': 43.449528000000001, 'lng': -70.792648}
# Have 6243 sites

# %%
from IPython.core.magics.display import Javascript
# Can only run one Javascript per cell, apparently
Javascript("window.center={};".format(json.dumps(center)))

# %%
Javascript("window.site_data={};".format(json.dumps(site_data)))

# %%
# %%javascript
# element.append('<div id="map" style="height:500px; border:solid 1px black"></div>');
# var GOOGLE_APIKEY = "AIzaSyBVM7ZuQXOyeFoFBWxyvDytf3G2WhV-Scg";
#
# var map;
# window.initMap = function() {
#     var map = new google.maps.Map(document.getElementById('map'), {
#     zoom: 6,
#     center: window.center,
#   });
# var heatMapData = [];
#
# for (var site_id in window.site_data) {
#     var site = window.site_data[site_id];
#     heatMapData.push({location: new google.maps.LatLng(parseFloat(site[0]), parseFloat(site[1])),
#                       weight:  Math.log(parseFloat(site[3]))})
# }
# var heatmap = new google.maps.visualization.HeatmapLayer({
#   data: heatMapData
# });
# heatmap.setMap(map);
#  /* // Uncomment for circles
#     for (var site_id in window.site_data) {
#         // Construct the circle for each value in citymap.
#         // Note: We scale the area of the circle based on the population.
#           // Add the circle for this city to the map.
#           var site = window.site_data[site_id];
#           //console.log("Site_id is "+site_id+" data is "+site[0]+","+site[1]);
#           var center = {lat: parseFloat(site[0]), lng: parseFloat(site[1])};
#           var siteCircle = new google.maps.Circle({
#             strokeColor: '#FF0000',
#             strokeOpacity: 0.8,
#             strokeWeight: 2,
#             fillColor: '#FF0000',
#             fillOpacity: 0.35,
#             map: map,
#             center: center,
#             radius: 100
#           });
#   }
#   */
# }
# $.getScript('https://maps.googleapis.com/maps/api/js?key='+GOOGLE_APIKEY+'&callback=initMap&libraries=visualization');
